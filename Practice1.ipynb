# %%
employee_names = ["Tareq", "Afsana", "Imtiaz", "Pulok", "Robin", "Samia", "Rupok"]

# %%
user_input = input("Enter a name or part of a name to search: ")

# %%
matches = [name for name in employee_names if user_input.lower() in name.lower()]

# %%
print("Matching names:", matches)
# Out:
# Matching names: ['Afsana', 'Samia']

# %%
employee_names = ["Tareq", "Afsana", "Imtiaz", "Pulok", "Robin", "Samia", "Rupok"]

user_input = input("Enter a name or part of a name to search: ")

matches = [name for name in employee_names if user_input.lower() in name.lower()]

print("Matching names:", matches)
# Out:
# Matching names: ['Afsana', 'Samia']
